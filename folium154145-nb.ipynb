# %%
# run this script to create a map from the passed in file
import folium
import pandas
import json
from statistics import mean

# %%
from geopy.geocoders import Nominatim

# %%
place_file = open("initial-10/places_154145.json")

# %%
place_data = json.load(place_file)

# %%
geolocator = Nominatim(user_agent = "NewsLens")

mapper = folium.Map(location=[45.5236, -122.6750])
topic = "154145"

# %%
def color(count):
    if count > 100:
        return 'red'
    elif count > 10:
        return 'orange'
    else:
        return 'green'

def lat_long(name):
    loc = geolocator.geocode(name, timeout=2000)
    if loc is not None:
        coords = [loc.latitude, loc.longitude]
        print(loc.address) 
        return coords
    return "*****not found: "  + name

# %%
fg = folium.FeatureGroup(name = "topic 23000")

places = {}
lat = []
long = []
for item in place_data:
    coords = lat_long(item['place_name'])
    if type(coords) is str:
        print(coords)
        continue
    lat += [coords[0]]
    long += [coords[1]]
    name = item['place_name']
    count = item['count']
    places.update({name: [count, lat_long]})
    fg.add_child(folium.Marker(location = coords, popup = folium.Popup(name),
        icon=folium.Icon(color=color(count),icon_color='green')))
# Out:
# 中国
# Philippines
# USA
# Manila, Fifth District, Manila, Metro Manila, Philippines
# 北京市, 东城区, 北京市, 100010, 中国
# Washington, D.C., USA
# 日本
# Việt Nam
# Malaysia
# РФ
# ປະເທດລາວ
# América, Resistencia, Departamento San Fernando, CCO, Argentina
# Mindanao, Valencia, Bukidnon, Northern Mindanao, Philippines
# Den Haag, Zuid-Holland, Nederland
# Ελλάδα
# Brunei
# Davao, Philippines
# Davao City, Davao, Philippines
# 臺灣, 信義鄉, 南投縣, 臺灣省, 臺灣
# Davao City, Davao, Philippines
# نجيب, إدلب, سوريا
# 東京, 千代田区, 東京都, 関東地方, 100-0002, 日本
# 조선민주주의인민공화국
# Australia
# Indonesia
# Singapore, Central, 178957, Singapore
# 대한민국
# Москва, Центральный административный округ, Москва, ЦФО, РФ
# ວຽງຈັນ, ເມືອງຈັນທະບູລີ, ນະຄອນຫຼວງວຽງຈັນ, 01003, ປະເທດລາວ
# Zamboanga City, Zamboanga Peninsula, 7000, Philippines
# Malawi
# Hà Nội, Việt Nam
# Summit County, Colorado, USA
# *****not found: Spratlys
# ประเทศไทย
# India
# Deutschland, Europe
# ព្រះរាជាណាចក្រ​កម្ពុជា
# Canada
# 香港 Hong Kong, 中西區 Central and Western District, 香港島 Hong Kong Island, HK, PACIFIC PLACE, 中国
# မြန်မာ
# 中国
# New Zealand/Aotearoa
# Dash, Dock Road, Foreshore, Cape Town, City of Cape Town, Western Cape, 8001, South Africa
# Danang, Wake Village, Port Royal, Beaufort County, South Carolina, 29905, USA
# Türkiye
# سورية
# Sulu, Autonomous Region in Muslim Mindanao, Philippines
# Hawaii, United States of America (Middle Hawai'ian Islands territorial waters)
# Palawan, Mimaropa, Philippines
# 평양, 중구역, 평양시, 조선민주주의인민공화국
# العراق
# Lima, Perú
# Malawi
# *****not found: Molly Koscina
# Rumana/Romana, SS, SAR, 07010, Italia
# Hilongos, Leyte 5th District, Leyte, Eastern Visayas, 6524, Philippines
# Dhal Sombath, ផ្លូវ​ជាតិ​លេខ​៥, សំពៅលូន, ខេត្តបាត់ដំបង, ព្រះរាជាណាចក្រ​កម្ពុជា
# Manila, Fifth District, Manila, Metro Manila, Philippines
# 杭州市, 江干区 (Jianggan), 杭州市 Hangzhou, 浙江省, 310026, 中国
# Luzón, Guadalajara, Castilla-La Mancha, España
# 대한민국
# Sulue, Ujué / Uxue, Navarra - Nafarroa, 31496, España
# السعودية
# Malawi
# Valletta, Malta
# Philippines
# Nederland
# Panatag, Addition Hills, Mandaluyong, Metro Manila, 1551, Philippines
# Genève, Schweiz/Suisse/Svizzera/Svizra
# Perú
# ישראל
# España
# Leyte, South Springville, Biñan, Laguna, Calabarzon, 4024, Philippines
# France métropolitaine, France
# Hagdang Bato Ibaba, Mandaluyong, Metro Manila, Philippines
# 贵阳市 / Guiyang, 黔, 中国
# ירושלים, מחוז ירושלים, ישראל
# Twitter, 1355, Market Street, Civic Center, SF, California, 94102, USA
# NYC, New York, USA
# Zamboanga City, Zamboanga Peninsula, 7000, Philippines
# KL, Malaysia
# រាជធានីភ្នំពេញ, ខណ្ឌដូនពេញ, រាជធានីភ្នំពេញ, 11213, ព្រះរាជាណាចក្រ​កម្ពុជា
# Roma, RM, LAZ, Italia
# Berlin, 10117, Deutschland
# 北京市, 东城区, 北京市, 100010, 中国
# Punisher, Bevan, Area C (Puntledge/Black Creek), Comox Valley Regional District, British Columbia, Canada
# Quezon, Calabarzon, Philippines
# Washington, D.C., USA
# United States of America
# Rodrigo, Santo Domingo, Villa Clara, Cuba
# Sydney, NSW, Australia
# Initiative, Babson Boulder Trail, Gloucester, Essex County, Massachusetts, 01930-3540, USA
# Makati City., 122, Valero, Salcedo, Bel-Air, Makati, Makati 1st District, Makati, Metro Manila, 1227, Philippines
# La Pernía, Palencia, Castilla y León, 34847, España
# San Diego, San Diego County, California, USA
# Spratly Islands, China 中国
# กรุงเทพมหานคร, ประเทศไทย
# Lamitan, Basilan, Autonomous Region in Muslim Mindanao, 7302, Philippines
# Lamitan, Basilan, Autonomous Region in Muslim Mindanao, 7302, Philippines
# Pagasa, Buenavista, Marinduque, Mimaropa, Philippines
# Монгол улс
# Basilan, Alabang Hills Village, Cupang, Muntinlupa, Metro Manila, 1771, Philippines
# Colombia
# London, Greater London, England, SW1A 2DU, UK
# 海南省, 中国
# Sabah, Malaysia
# Zambales, Luzviminda Village, Batasan Hills, Commonwealth, District II, Quezon City, Metro Manila, 1126, Philippines
# Україна
# Florida, USA
# Macy, Miami County, Indiana, USA
# Zamboanga City, Zamboanga Peninsula, 7000, Philippines
# Norge, Ytterbyvegen, Namsos, Trøndelag, 7810, Norge
# Rua Professor Naoki Kishida, Sítio Cercado, Curitiba, Microrregião de Curitiba, RMC, Mesorregião Metropolitana de Curitiba, PR, Região Sul, 81850-000, Brasil
# Moros, Zaragoza, Aragón, España
# UK
# Lanao, Kidapawan City, Cotabato, Soccsksargen, 9400, Philippines
# Quang, La Hoi, Cẩm Nam, Hội An, Tỉnh Quảng Nam, 0510, Việt Nam
# Norge, Ytterbyvegen, Namsos, Trøndelag, 7810, Norge
# JKT, Indonesia
# Bangladesh, Bhabanipur, ময়মনসিংহ বিভাগ, বাংলাদেশ
# SCS, Plano Piloto, Região Integrada de Desenvolvimento do Distrito Federal e Entorno, DF, Região Centro-Oeste, Brasil
# MLK, Malaysia
# Pampanga, Magsaysay Village, Tondo, Second District, Manila, Metro Manila, 1013, Philippines
# Pinol, Sarangani, Soccsksargen, Philippines
# افغانستان
# Hader, NB, Bayern, 94167, Deutschland
# Pasay, District 1, Pasay, Metro Manila, 1300, Philippines
# Chito, Chinchipe, Zamora Chinchipe, Ecuador
# UK
# Burundi
# Tondo, Manila, First District, Manila, Metro Manila, 1012, Philippines
# Pangasinan, Ilocos, Philippines
# *****not found: GlangZAMBOANGA CITY
# BXL, Brussel-Hoofdstad - Bruxelles-Capitale, Région de Bruxelles-Capitale - Brussels Hoofdstedelijk Gewest, 1000, België / Belgique / Belgien
# Ísland
# Pasay, District 1, Pasay, Metro Manila, 1300, Philippines
# 瀾滄江 Lancang - Mekong - แม่น้ำโขง, 勐腊县 (Mengla), 西双版纳州, 云南省, 666100, 中国
# Boracay, Malay, Aklan, Western Visayas, 5608, Philippines
# ‏ایران‎
# *****not found: VideoMANILA
# Quezon City, District IV, Quezon City, Metro Manila, 1100, Philippines
# El Suga, Unknown, Somali, ኢ.ፌ.ዲ.ሪ.
# Battlefield, Hempstead County, Arkansas, USA
# ကရင်ပြည်နယ (Kayin), မြန်မာ
# Rubicone, Unione Rubicone e mare, FC, EMR, 47043, Italia
# вид на деревню Диджясалис (Литва), Р27, Морозовка, Видзовский сельский Совет, Браславский район, Витебская область, 211970, Беларусь
# *****not found: PhilippinesDAVAO
# India
# 沖縄県, 県道18号, 名護市, 沖縄県, 九州地方, 9050017, 日本
# Butig, Lanao del Sur, Autonomous Region in Muslim Mindanao, 9305, Philippines
# Bacolod, Negros Occidental, Western Visayas, 6100, Philippines
# Leyte, Javier, Leyte 5th District, Leyte, Eastern Visayas, 6511, Philippines
# Tp HCM, Việt Nam
# Philippines
# Калашников, Саратовский район, Саратовская область, Приволжский федеральный округ, РФ
# Ελλάδα
# road, မုဒုံ, Mawlamyine, Mon, မြန်မာ
# s, Northern Samar, Eastern Visayas, Philippines
# Investment, SSS Employees Housing Project, North Fairview, District V, Quezon City, Metro Manila, 1118, Philippines
# Italia
# The City, 1863, Avenida Fernández Juncos, San Mateo, Santurce, Río Piedras, San Juan, Puerto Rico, 00910, USA
# 横浜市, 神奈川県, 関東地方, 日本
# 辽宁省, 中国
# Cotabato City, Maguindanao, Soccsksargen, 9600, Philippines
# Taguig, Metro Manila, Philippines
# Paris, Île-de-France, France métropolitaine, France
# San Antonio, Bexar County, Texas, USA
# 厦门市, 思明区, 厦门市 / Xiamen, 福建省, 361001, 中国
# The Lawyer, 12-14, Wensum Street, New Catton, Norwich, Norfolk, East of England, England, NR3 1HY, UK
# *****not found: MANILAWASHINGTON
# Philippine Sea
# Lincuna Store, Surigao - Davao Coastal Road, Usok, Ladgaron, Surigao Del Norte, Caraga, 8410, Philippines
# And That!, Carl D Silver Parkway, Central Park, Fredericksburg, Fredericksburg City, Virginia, 22401, USA
# الرياض, منطقة الرياض, 11131, السعودية
# Tawi Tawi, Autonomous Region in Muslim Mindanao, Philippines
# Beijing 2008, Villa Oro Olímpico, Esmeralda, Colina, Provincia de Chacabuco, Región Metropolitana de Santiago, Chile
# Zaldy House, Acacia, Diho 4 Subdivision, Poblacion, Davao City, Davao, 8000, Philippines
# Cotabato City, Maguindanao, Soccsksargen, 9600, Philippines
# San Miguel County, Colorado, USA
# El Roque, Adeje, Santa Cruz de Tenerife, Canarias, 38640, España
# 新疆维吾尔自治区, 中国
# 日本
# *****not found: Bulanting village
# Canberra, Canberra Central, Australian Capital Territory, 2600, Australia
# Rua Domingos Primiano, São Lourenço do Turvo, Matão, Microrregião de Araraquara, Mesorregião de Araraquara, SP, Região Sudeste, Brasil
# Pasig, Metro Manila, 1601, Philippines
# *****not found: Walden Bello
# North Arbitrary Street, Roseville, Warren County, Illinois, 61473, USA
# *****not found: PhilippinesBORACAY
# اليمن
# بغداد, الكرخ, محافظة بغداد, العراق
# Missouri, USA
# Sverige
# *****not found: nL4N1F23AK][nL4N1F32FB
# *****not found: Bulatlat
# The Struggle, Lakes, South Lakeland, Cumbria, North West England, England, LA22 9LQ, UK
# Le Canon, Molas, Saint-Gaudens, Haute-Garonne, Occitanie, France métropolitaine, 31230, France
# Pampanga, Central Luzon, Philippines
# Honolulu, Honolulu County, Hawaii, USA
# ليبيا
# Summary Street, Modern Manor Mobile Home Park, Johnson County, Iowa, 52240, USA
# *****not found: Sea Disputes
# *****not found: obligationThe United States
# Việt Nam
# Malaysia
# South Africa
# *****not found: Misinformed
# Maguindanao, Autonomous Region in Muslim Mindanao, Philippines
# Melania, El Bosque, Provincia de Santiago, Región Metropolitana de Santiago, 8010000, Chile
# Quezon City, District IV, Quezon City, Metro Manila, 1100, Philippines
# Soomaaliya الصومال
# Destroy, Jičínská, Žižkov, Praha, okres Hlavní město Praha, Hlavní město Praha, Praha, 13000, Česko
# Pag-asa, Santa Josefa, Agusan del Sur, Caraga, Philippines
# Breakfast, Plaza, Vilama, San Pedro de Atacama, Provincia de El Loa, II Región de Antofagasta, 1410000, Chile
# Suomi
# La Romana, Paine, Provincia de Maipo, Región Metropolitana de Santiago, Chile
# *****not found: Russelas
# Tuguegarao, Cagayan, Cagayan Valley, 3500, Philippines
# *****not found: Prince Mikasa
# *****not found: nL4N1CP1QW
# Video, Microrregião de Quitéria, Mesorregião Noroeste Cearense, CE, Região Nordeste, Brasil
# الموصل, قضاء الموصل, نینوى, 5555, العراق
# Maasin, Southern Leyte, Eastern Visayas, Philippines
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-328d2023723b> in <module>()
#       5 long = []
#       6 for item in place_data:
# ----> 7     coords = lat_long(item['place_name'])
#       8     if type(coords) is str:
#       9         print(coords)
#
# <ipython-input-35-02a140321b0c> in lat_long(name)
#       8
#       9 def lat_long(name):
# ---> 10     loc = geolocator.geocode(name, timeout=2000)
#      11     if loc is not None:
#      12         coords = [loc.latitude, loc.longitude]
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags)
#     305
#     306         return self._parse_json(
# --> 307             self._call_geocoder(url, timeout=timeout), exactly_one
#     308         )
#     309
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     342
#     343         try:
# --> 344             page = requester(req, timeout=timeout, **kwargs)
#     345         except Exception as error:
#     346             message = (
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1390
#    1391             self.sock = self._context.wrap_socket(self.sock,
# -> 1392                                                   server_hostname=server_hostname)
#    1393
#    1394     __all__.append("HTTPSConnection")
#
# /anaconda3/lib/python3.7/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     410             server_hostname=server_hostname,
#     411             context=self,
# --> 412             session=session
#     413         )
#     414
#
# /anaconda3/lib/python3.7/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     848                         # non-blocking
#     849                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 850                     self.do_handshake()
#     851             except (OSError, ValueError):
#     852                 self.close()
#
# /anaconda3/lib/python3.7/ssl.py in do_handshake(self, block)
#    1106             if timeout == 0.0 and block:
#    1107                 self.settimeout(None)
# -> 1108             self._sslobj.do_handshake()
#    1109         finally:
#    1110             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
mapper = folium.Map(location=[mean(lat), mean(long)], zoom_start=3, tiles='Mapbox bright')

mapper.add_child(fg)

mapper.add_child(folium.LayerControl())
mapper.save(outfile='map' + topic + '.html')
